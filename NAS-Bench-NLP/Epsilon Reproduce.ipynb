# %% [markdown]
# # Epsilon metric reproduction
#
# If you wish to reproduce the results presented in our paper from scratch, feel free to use the below code. Since\
# the version of torch used by the authors of NAS-Bench-NLP is too old, we run our tests on everything on CPU. \
# While the procedure is quite light, it still took us several hours to evaluate the whole benchmark dataset of over\
# 14k architectures.
#
# We provide the codes to reproduce the results for single run and multiple runs architectures on PennTreebank data.

# %%
import os
import json
import data

import numpy as np
import pickle as pkl
import seaborn as sns
from tqdm import trange

import torch.nn as nn

from utils import batchify
from argparse import Namespace
from model import AWDRNNModel
from train import train, evaluate
from utils import get_batch
from multilinear import MultiLinear
from custom_rnn import CustomRNNCell, CustomRNN
from weight_drop import ParameterListWeightDrop
from epsilon_utils import prepare_seed, prepare_recepies

# %% [markdown]
# ## Single run with Penn Tree Bank
#
# 14322 randomly created architectures are trained with a single seed.
#
# Note: this procedure takes about 5 hours on CPU.

# %%
# Prepare a fixed batch of data
file_list=os.listdir("train_logs_single_run/")
log_dflt = json.load(open('train_logs_single_run/' + file_list[0], 'r'))
args = Namespace(**log_dflt)
corpus = data.Corpus(args.data)

ntokens = len(corpus.dictionary)
batch_size = 256

train_eval_data = batchify(corpus.train, batch_size, args, "cpu")
x, _ = get_batch(train_eval_data, 0, args, evaluation=True)

# %%
# Setting up the weights
weight_l = 1e-5
weight_h = 1e-3

# %%
accs = []
nparams = []

score = []

for i in trange(len(file_list)):
    file = file_list[i]
    log = json.load(open('train_logs_single_run/' + file, 'r'))
    args = Namespace(**log)

    # Build the model
    network = AWDRNNModel(args.model,
                          ntokens,
                          args.emsize,
                          args.nhid,
                          args.nlayers,
                          args.dropout,
                          args.dropouth,
                          args.dropouti,
                          args.dropoute,
                          args.wdrop,
                          args.tied,
                          args.recepie,
                          verbose=False)
    print(network.modules)
    preds = []
    for weight in [weight_l, weight_h]:
        # Initialize
        prepare_seed(21)
        def initialize_resnet(m):
            if type(m)==MultiLinear:
                for par in m.weights_raw:
                    nn.init.constant_(par, weight)
            elif type(m)==CustomRNNCell:
                for par in m.parameters():
                    nn.init.constant_(par, weight)
            elif type(m)==nn.modules.linear.Linear:
                nn.init.constant_(m.weight, weight)
            elif type(m)==nn.modules.container.ParameterList:
                for par in m.parameters():
                    nn.init.constant_(par, weight)
            elif type(m)==CustomRNN:
                initialize_resnet(m.cell)
            elif type(m)==ParameterListWeightDrop:
                initialize_resnet(m.module)
            elif type(m)==nn.modules.container.ModuleDict:
                for sub_m in m:
                    initialize_resnet(sub_m)
            elif type(m)==nn.modules.container.ModuleList:
                for sub_m in m:
                    initialize_resnet(sub_m)
            elif type(m)==AWDRNNModel:
                initialize_resnet(m.rnns)

        network.apply(initialize_resnet)
        network.eval()
        hidden = network.init_hidden(batch_size, weight)
        # Take care of embedding is not constant
        nn.init.uniform_(network.encoder.weight, 0, 1)
        _, _, raw_output, _ = network(x, hidden=hidden, return_h=True)
        pred = raw_output[-1][:,:,0].flatten()
        pred = pred.numpy()
        pred_min = np.nanmin(pred)
        pred_max = np.nanmax(pred)
        pred_norm = (pred - pred_min)/(pred_max - pred_min)
        preds.append(pred_norm)

    # Compute the score
    preds = np.array(preds)
    preds[np.where(preds==0)] = np.nan
    mae = np.nanmean(np.abs(preds[0,:]-preds[1,:]))
    mean = np.nanmean(preds)
    score.append(mae/mean)
    
    try:
        accs.append(log['test_losses'][-1])
    except:
        # Some architectures have no reported test perplexity
        accs.append(np.nan)
    nparams.append(args.num_params)
    
# Save your results
save_dir = './results/NLP/PTB/SINGLE/WEIGHT_{}_{}/BS{}/'.format(weight_l, weight_h, batch_size)
os.makedirs(save_dir, exist_ok=True)

save_dic = {}
save_dic["score"] = score
save_dic["accs"] = accs
save_dic["nparams"] = nparams
    
pkl.dump(save_dic, open(save_dir + "Data", "wb"))
# Out:
#   0%|                                                                                                    | 0/14322 [00:00<?, ?it/s]/home/gracheva/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_7): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_7): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_7): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 1/14322 [00:00<2:55:16,  1.36it/s]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[400, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_10): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_15): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_10): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_15): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[400, 600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_10): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_15): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 2/14322 [00:02<6:13:01,  1.56s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 3/14322 [00:04<5:25:39,  1.36s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[400, 400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 4/14322 [00:05<5:44:51,  1.45s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_2): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_11): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_13): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_11): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_13): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_2): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[400, 400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_11): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_13): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 5/14322 [00:07<5:55:42,  1.49s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_16): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_16): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[400, 400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_16): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 6/14322 [00:08<5:40:26,  1.43s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_12): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
# /home/gracheva/miniconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in true_divide
# /home/gracheva/miniconda3/envs/tf2/lib/python3.7/site-packages/ipykernel_launcher.py:71: RuntimeWarning: Mean of empty slice
#   0%|                                                                                          | 7/14322 [00:09<5:21:24,  1.35s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_3): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_7): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_9): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                          | 8/14322 [00:11<5:25:37,  1.36s/it]
# <bound method Module.modules of AWDRNNModel(
# ...
#                   (2): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 400], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x400]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_3): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_3): MultiLinear(
#               input_sizes=[400, 400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#             (node_5): MultiLinear(
#               input_sizes=[400, 600], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x600]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                         | 11/14322 [00:14<4:36:05,  1.16s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
#   0%|                                                                                         | 12/14322 [00:15<5:05:12,  1.28s/it]
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[400, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (2): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_2): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_4): MultiLinear(
#               input_sizes=[600, 400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (2): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_6): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (node_8): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): None
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_7616/135651936.py in <module>
#      58         # Take care of embedding is not constant
#      59         nn.init.uniform_(network.encoder.weight, 0, 1)
# ---> 60         _, _, raw_output, _ = network(x, hidden=hidden, return_h=True)
#      61         pred = raw_output[-1][:,:,0].flatten()
#      62         pred = pred.numpy()
#
# ~/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Work/NAS/Epsilon-NAS/NAS-Bench-NLP/model.py in forward(self, input, hidden, return_h)
#      93             outputs = []
#      94             for i, rnn in enumerate(self.rnns):
# ---> 95                 raw_output, new_h = rnn(raw_output, hidden[i])
#      96                 raw_outputs.append(raw_output)
#      97                 if i != self.nlayers - 1:
#
# ~/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Work/NAS/Epsilon-NAS/NAS-Bench-NLP/weight_drop.py in forward(self, *args)
#     101     def forward(self, *args):
#     102         self._setweights()
# --> 103         return self.module.forward(*args)
#
# ~/Work/NAS/Epsilon-NAS/NAS-Bench-NLP/custom_rnn.py in forward(self, inputs, hidden_tuple)
#     101         outputs = []
#     102         for x in torch.unbind(inputs, dim=0):
# --> 103             hidden_tuple = self.cell(x, hidden_tuple)
#     104             outputs.append(hidden_tuple[0].clone())
#     105
#
# ~/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Work/NAS/Epsilon-NAS/NAS-Bench-NLP/custom_rnn.py in forward(self, x, hidden_tuple)
#      60             elif n in self.components:
#      61                 inputs = [calculated_nodes[k] for k in self.recepie[n]['input']]
# ---> 62                 calculated_nodes[n] = self.components[n](*inputs)
#      63             else:
#      64                 # simple operations
#
# ~/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/Work/NAS/Epsilon-NAS/NAS-Bench-NLP/multilinear.py in forward(self, *inputs)
#      32         result = F.linear(inputs[0], self.weights[0], self.bias)
#      33         for i in range(1, len(self.weights)):
# ---> 34             result = result + F.linear(inputs[i], self.weights[i])
#      35         return result
#      36
#
# ~/miniconda3/envs/tf2/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
# -> 1692         output = input.matmul(weight.t())
#    1693         if bias is not None:
#    1694             output += bias
#
# KeyboardInterrupt:

# %%
network.modules
# Out:
# <bound method Module.modules of AWDRNNModel(
#   (lockdrop): LockedDropout()
#   (idrop): Dropout(p=0.4, inplace=False)
#   (hdrop): Dropout(p=0.25, inplace=False)
#   (drop): Dropout(p=0.1, inplace=False)
#   (encoder): Embedding(10000, 400)
#   (rnns): ModuleList(
#     (0): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[400, 600], output_size=600
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (1): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[600, 600], output_size=600
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 600x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 600x600]
#               )
#             )
#           )
#         )
#       )
#     )
#     (2): ParameterListWeightDrop(
#       (module): CustomRNN(
#         (cell): CustomRNNCell(
#           (components): ModuleDict(
#             (node_0): MultiLinear(
#               input_sizes=[400, 400], output_size=400
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x400]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#             (h_new_1): MultiLinear(
#               input_sizes=[600, 400], output_size=400
#               (weights): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#               (weights_raw): ParameterList(
#                   (0): Parameter containing: [torch.FloatTensor of size 400x600]
#                   (1): Parameter containing: [torch.FloatTensor of size 400x400]
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (decoder): Linear(in_features=600, out_features=10000, bias=True)
# )>

# %% [markdown]
# ## Multiple runs with Penn Tree Bank
#
# 4114 randomly created architectures trained with 3 random seeds.
#
# Note: this procedure takes about 1.5 hours on CPU.

# %%
# Prepare a fixed batch of data
file_list=os.listdir("train_logs_multi_runs/")
log_dflt = json.load(open('train_logs_multi_runs/' + file_list[0], 'r'))
args = Namespace(**log_dflt)
corpus = data.Corpus(args.data)

ntokens = len(corpus.dictionary)
batch_size = 256

train_eval_data = batchify(corpus.train, batch_size, args, "cpu")
x, _ = get_batch(train_eval_data, 0, args, evaluation=True)

# %%
recepie_dic = prepare_recepies()
recepies = list(recepie_dic.keys())

# %%
accs_mean = []
accs_min = []
accs_max = []
nparams = []

score = []

for i in trange(len(recepie_dic)):
    rec = recepies[i]
    indices = recepie_dic[rec]
    # As for the same recepie the metric performance does not change,
    # we only need to compute it once
    file = file_list[indices[0]]
    log = json.load(open('train_logs_multi_runs/' + file, 'r'))
    args = Namespace(**log)

    # Build the model
    network = AWDRNNModel(args.model,
                          ntokens,
                          args.emsize,
                          args.nhid,
                          args.nlayers,
                          args.dropout,
                          args.dropouth,
                          args.dropouti,
                          args.dropoute,
                          args.wdrop,
                          args.tied,
                          args.recepie,
                          verbose=False)
    preds = []
    for weight in [weight_l, weight_h]:
        # Initialize
        prepare_seed(21)
        def initialize_resnet(m):
            if type(m)==MultiLinear:
                for par in m.weights_raw:
                    nn.init.constant_(par, weight)
            elif type(m)==CustomRNNCell:
                for par in m.parameters():
                    nn.init.constant_(par, weight)
            elif type(m)==nn.modules.linear.Linear:
                nn.init.constant_(m.weight, weight)
            elif type(m)==nn.modules.container.ParameterList:
                for par in m.parameters():
                    nn.init.constant_(par, weight)
            elif type(m)==CustomRNN:
                initialize_resnet(m.cell)
            elif type(m)==ParameterListWeightDrop:
                initialize_resnet(m.module)
            elif type(m)==nn.modules.container.ModuleDict:
                for sub_m in m:
                    initialize_resnet(sub_m)
            elif type(m)==nn.modules.container.ModuleList:
                for sub_m in m:
                    initialize_resnet(sub_m)
            elif type(m)==AWDRNNModel:
                initialize_resnet(m.rnns)

        network.apply(initialize_resnet)
        network.eval()
        hidden = network.init_hidden(batch_size, weight)
        # Take care of embedding is not constant
        nn.init.uniform_(network.encoder.weight, 0, 1)
        _, _, raw_output, _ = network(x, hidden=hidden, return_h=True)
        pred = raw_output[-1][:,:,0].flatten()
        pred = pred.numpy()
        pred_min = np.nanmin(pred)
        pred_max = np.nanmax(pred)
        pred_norm = (pred - pred_min)/(pred_max - pred_min)
        preds.append(pred_norm)

    # Compute the score
    preds = np.array(preds)
    preds[np.where(preds==0)] = np.nan
    mae = np.nanmean(np.abs(preds[0,:]-preds[1,:]))
    mean = np.nanmean(preds)
    score.append(mae/mean)
    
    # Retrive 3 seeds test errors
    acc_run = []
    for ind in indices:
        file = file_list[ind]
        log = json.load(open('train_logs_multi_runs/' + file, 'r'))
        args = Namespace(**log)
        try:
            acc_run.append(log['test_losses'][-1])
        except: 
            acc_run.append(np.nan)
            
    accs_mean.append(np.nanmean(acc_run))
    accs_min.append(np.nanmin(acc_run))
    accs_max.append(np.nanmax(acc_run))
    nparams.append(args.num_params)

# Save your results
save_dir = './results/NLP/PTB/MULTI/WEIGHT_{}_{}/BS{}/'.format(weight_l, weight_h, batch_size)
os.makedirs(save_dir, exist_ok=True)

save_dic = {}
save_dic["score"] = score
save_dic["accs_mean"] = accs_mean
save_dic["accs_min"] = accs_min
save_dic["accs_max"] = accs_max
save_dic["nparams"] = nparams
    
pkl.dump(save_dic, open(save_dir + "Data", "wb"))
